# %% [markdown]
# # <span style="color:Navy">**MLM Project 2**
# # <span style="color:Navy">**Supervised Learning Models on Import-Export Dataset using Python**
#
#
#
# ---
#
#
#
# ## <span style="color:Navy">**PROJECT CONTENTS:**
# - Project Information
# - Description of Data
# - Data Sampling
# - Project Objectives | Problem Statements
# - Analysis of Data
# - Observations | Findings
# - Managerial Insights | Recommendations
#
# ---
#
# ### <span style="color:Navy">**1. Project Information**
# - **Title**: Data Exploration with Python using Pandas & Numpy Libraries
#
#
#  <span style="color:Navy">**Prepared By:**
#
# - **Rohan Jha** (055057)
#
#
# ---
#
# ### <span style="color:Navy">**2. Description of Data**
# - **Data Source**: https://www.kaggle.com/datasets/chakilamvishwas/imports-exports-15000
#
#   A live link is used in the dataset
#
# - **Data Columns Description**:
#   - **Transaction_ID**: Unique identifier for each trade transaction.
#   - **Country**: Country of origin or destination for the trade.
#   - **Product**: Product being traded.
#   - **Import_Export**: Indicates whether the transaction is an import or export.
#   - **Quantity**: Amount of the product traded.
#   - **Value**: Monetary value of the product in USD.
#   - **Date**: Date of the transaction.
#   - **Category**: Category of the product (e.g., Electronics, Clothing, Machinery).
#   - **Port**: Port of entry or departure.
#   - **Customs_Code**: Customs or HS code for product classification.
#   - **Weight**: Weight of the product in kilograms.
#   - **Shipping_Method**: Method used for shipping (e.g., Air, Sea, Land).
#   - **Supplier**: Name of the supplier or manufacturer.
#   - **Customer**: Name of the customer or recipient.
#   - **Invoice_Number**: Unique invoice number for the transaction.
#   - **Payment_Terms**: Terms of payment (e.g., Net 30, Net 60, Cash on Delivery).
#
# - **Data Type**: Since the dataset contains multiple entities (countries) and records data over time, this is an example of Panel Data (also called longitudinal data).
#
# - **Data Variables**:
#   - **All non-null Variables**
#     - **Numbers**:
#       - Integer Variables: 3 (Quantity, Customs_Code, Invoice_Number)
#       - Float (Decimal) Variables: 2 (Value, Weight)
#     - **Text**: 9 (Country, Product, Import_Export, Category, Port, Shipping_Method, Supplier, Customer, Payment_Terms)
#     - **DateTime**: 1 (Date)
#
# ---
#
# ### <span style="color:Navy">**3. Data Sampling**
# From the dataset containing 15,000 values, a sample of 5001 entries was taken. The dataset sample (now referred to as `RJ57_sample`) was taken into account for further exploration.
#
# - **Data Variables**:
#   - **Index Variables**: 'Transaction_ID', 'Invoice_Number'
#   - **Categorical Variables**:
#     - Nominal Variables: Country, Product, Import_Export, Category, Port, Shipping_Method, Supplier, Customs_Code, Customer
#     - Ordinal Variable: Payment_Terms
#   - **Non-Categorical Variables**: Quantity, Value, and Weight
#
# ---
#
# ### <span style="color:Navy">**4. Project Objectives**
#
# -   Classification of Dataset into {Segments | Clusters | Classes} using Supervised Learning Classification Algorithms
# -   Identification of {Important | Contributing | Significant} Variables or Features and their Thresholds for Classification
# -   Determination of an appropriate Classification Model based on Performance Metrics
# ---
# ### **5. Exploratory Data Analysis**
#
# #### **5.1. Data Preprocessing:**
#
# -   The data has no missing values, hence no missing data treatment was performed.
# -   For Encoding,  **Ordinal Encoder**  was used.
# -   For Scaling,  **Min-Max Scaler**  was used.
#
# #### **5.2. Descriptive Statistics**
#
# -   **Non-Categorical Variables**:
#
#     -   Measures of Central Tendency: Minimum, Maximum, Mean, Median, Mode, Percentile
#     -   Measures of Dispersion: Range, Standard Deviation, Skewness, Kurtosis, Correlation (Matrix)
#     -   Composite Measure: Coefficient of Variation, Confidence Interval
# -   **Categorical Variables**:
#
#     -   Count, Frequency, Proportion, Minimum, Maximum, Mode, Rank
#
# #### **5.3. Data Visualization**
#
# -   Various subplots were used such as Bar, Heatmaps, Histograms, and Correlation Matrices.
#
# #### **5.4. Inferential Statistics**
#
# -   **Categorical Variable**  (Nominal | Ordinal):
#     -   Test of Homogeneity (Chi-sq)
# -   **Non-Categorical Variable**:
#     -   Test of Normality (Shapiro-Wilk, Kolmogorov-Smirnov, Anderson-Darling, Jarque-Bera)
#     -   Test of Correlation (t)
#
# #### **5.5. Machine Learning Models**
#
# -   **Logistic Regression (LR)**: Logistic regression is a classification algorithm that models the probability of a binary outcome based on one or more predictor variables using a logistic function.
#
# -   **Support Vector Machines (SVM)**: SVM finds a hyperplane that best separates the data into classes by maximizing the margin between the closest points of the classes (support vectors).
#
# -   **Stochastic Gradient Descent (SGD)**: An iterative optimization algorithm used for minimizing loss functions in linear classifiers and regressors, particularly useful for large datasets.
#
# -   **Decision Trees**: A tree-based algorithm where each internal node represents a decision on a feature, each leaf node represents an outcome, and paths from root to leaf represent classification rules.
#
# -   **K-Nearest Neighbors (KNN)**: A lazy learning algorithm that classifies a data point based on the majority class of its k-nearest neighbors in the feature space.
#
# -   **Naive Bayes (NB)**: A probabilistic classifier based on Bayes' theorem, assuming strong independence between features.
#
# -   **Bagging (Bootstrap Aggregating)**: Combines predictions from multiple models (e.g., Random Forest) to reduce variance and improve accuracy.
#
# -   **Boosting**: Combines weak learners sequentially to form a strong learner by minimizing errors iteratively (e.g., Extreme Gradient Boosting - XGBoost).
#
#
# #### **5.6. Model Performance Metrics**
#
# -   **Confusion Matrix**:
#
#     -   Sensitivity (Recall): True Positive Rate
#     -   Specificity: True Negative Rate
#     -   Accuracy: Overall correctness
#     -   Precision: Positive Predictive Value
#     -   F1-Score: Harmonic mean of Precision and Recall
#     -   AUC: Area Under the ROC Curve
# -   **K-Fold Cross-Validation**: Splits data into k subsets; trains on k-1 and tests on the remaining one iteratively to ensure robust performance evaluation.
#
# -   **Model Run Statistics**:
#
#     -   Time Taken
#     -   Memory Used
#     -   Inherent Complexity
#
# ### **6. Observations and Findings**
#
# **6.1. Nature of Data**
#
# -   **Missing Data:** The dataset contained no missing values.
# -   **Non-Numeric Categorical Data:** Categorical variables (e.g., Country, Product) were encoded using ordinal encoding.
# -   **Scales and Outliers:** Non-categorical numeric data (Quantity, Value, Weight) were scaled using Min-Max scaling. Box plots revealed potential outliers, but they were not removed to avoid potential loss of valuable information.
#
# **6.2. Supervised Machine Learning**
#
# -   **Logistic Regression (LR) vs. Support Vector Machine (SVM)**
#
#     -   **Performance Metrics:** LR Accuracy: 0.3491, SVM Accuracy: 0.3298. LR showed slightly better performance.
#     -   **Run Statistics:** LR was significantly faster (0.0255 seconds) than SVM (0.7741 seconds). SVM had slightly lower memory usage (0.28 MB vs. 0.34 MB for LR).
#     -   **Conclusion:** LR is preferred due to its faster runtime and lower memory usage, making it more suitable for time-sensitive applications.
# -   **Decision Tree (DT) vs. K-Nearest Neighbors (KNN)**
#
#     -   **Performance Metrics:** DT Accuracy: 0.3331, KNN Accuracy: 0.3258. DT showed slightly better accuracy.
#     -   **Run Statistics:** KNN was significantly faster (0.0051 seconds) than DT (0.0288 seconds).
#     -   **Conclusion:** DT is preferred for its slightly higher accuracy and better interpretability. KNN might be suitable when speed is the primary concern.
# -   **Logistic Regression (LR) vs. Decision Tree (DT)**
#
#     -   **Performance Metrics:** LR Accuracy: 0.3491, DT Accuracy: 0.3331. LR showed slightly better accuracy.
#     -   **Run Statistics:** LR was faster (0.0255 seconds) than DT (0.0288 seconds).
#     -   **Conclusion:** LR is favored due to its slightly better accuracy and faster runtime.
# -   **Decision Tree (DT) vs. Random Forest (RF)**
#
#     -   **Performance Metrics:** DT Accuracy: 0.3331, RF Accuracy: 0.3498. RF showed significantly better accuracy.
#     -   **Run Statistics:** DT was significantly faster (0.0288 seconds) than RF (1.0311 seconds). RF consumed more memory (0.49 MB vs. 0.23 MB for DT).
#     -   **Conclusion:** RF may be more effective for larger, more complex datasets, but DT is preferred for faster training and lower memory usage.
# -   **Cross-Validation of Results and Performance**
#
#     -   **Logistic Regression:**
#
#         -   Mean Cross-Validation Accuracy: 0.3437
#         -   Test Set Accuracy: 0.3491
#         -   Observations: Shows relatively balanced performance across classes.
#     -   **Support Vector Machine (SVM):**
#
#         -   Mean Cross-Validation Accuracy: 0.3266
#         -   Test Set Accuracy: 0.3298
#         -   Observations: Shows some bias towards certain classes.
#     -   **Decision Tree (DT):**
#
#         -   Mean Cross-Validation Accuracy: 0.3360
#         -   Test Set Accuracy: 0.3331
#         -   Observations: Consistent performance across classes.
#     -   **Random Forest (RF):**
#
#         -   Mean Cross-Validation Accuracy: 0.3360
#         -   Test Set Accuracy: 0.3498
#         -   Observations: Shows improved accuracy compared to DT.
#
# ### **7. Managerial Insights and Recommendations**
#
# **7.1. Preprocessing of Data**
#
# -   **Missing Data:** No specific treatment was necessary due to the absence of missing values.
# -   **Encoding:** Ordinal encoding was effective for categorical variables.
# -   **Scaling:** Min-Max scaling was used to address potential scale differences.
# -   **Data Split:** A 70:30 split for training and testing sets is recommended for future supervised learning tasks.
#
# **7.2. Supervised Machine Learning**
#
# -   **Inference regarding the Purpose of Classification:** The purpose of classification is to identify patterns in the data and accurately assign instances to predefined classes. The models exhibited varying levels of accuracy, suggesting potential challenges such as class imbalance or insufficient data quality.
#
# -   **Model Selection:**
#
#     -   **Logistic Regression:** Suitable for quick analysis and interpretability, especially when time and computational resources are limited.
#     -   **Decision Tree:** Provides good interpretability and can handle moderate complexity.
#     -   **Support Vector Machine:** Effective for capturing complex patterns but can be computationally expensive.
#     -   **Random Forest:** Can improve accuracy over Decision Trees, but requires more computational resources.
# -   **Recommendations for Managerial Actions:**
#
#     -   **Address class imbalance** using techniques like oversampling or undersampling.
#     -   **Improve feature engineering** to enhance model performance.
#     -   **Select models** based on the trade-off between accuracy, runtime, and interpretability.
#     -   **Continuously monitor and refine** the models as new data becomes available.
#
# **Identification of Important Variables or Features and Their Thresholds**
#
# -   **Key Features:** Country, Product, Quantity, Value, Weight, Shipping_Method, Port, and Customs_Code consistently emerged as significant features across multiple models.
# -   **Model-Specific Observations:**
#     -   **Decision Tree:** Relied heavily on Country, Product, Quantity, and Value.
#     -   **Random Forest:** Benefited from ensemble averaging, utilizing features like Port and Customs_Code effectively.
#     -   **XGBoost:** Highlighted the importance of Product, Country, and Value based on feature importance scores.
#     -   **KNN:** Emphasized Quantity and Weight due to its distance-based nature.
#     -   **Naive Bayes:** Primarily relied on categorical features like Import_Export, Customs_Code, and Shipping_Method.
#     -   **Logistic Regression:** Found Country, Product, and Shipping_Method to be significant predictors.

# %% [markdown]
# ## **Project Information and Analysis**

# %%
# Import Relevant Python Libraries

from io import StringIO
import requests
import pandas as pd
import statsmodels.formula.api as sm
from scipy.stats import chi2_contingency
from scipy.stats import shapiro, kstest, anderson, jarque_bera
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, DBSCAN, Birch
from scipy.cluster.hierarchy import dendrogram, linkage
import statsmodels.stats.descriptivestats as dstats
import numpy as np  # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder  # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.impute import SimpleImputer, KNNImputer  # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler  # For Rescaling Data
from sklearn.model_selection import train_test_split  # For Splitting Data into Training & Testing Sets
import matplotlib.pyplot as plt
import seaborn as sns  # For Data Visualization
import scipy.cluster.hierarchy as sch  # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus  # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score,davies_bouldin_score  # For Clustering Model Evaluation
import statsmodels.api as sm
from sklearn import metrics
import scipy.stats as stats
import statsmodels.stats.multicomp as multi
import warnings
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score



warnings.filterwarnings('ignore')

# %%
import io # import the io module

# Replace with your Google Drive file ID.
RJ57_file_id = '1kV2diCusZJv9q2uRWPg2HzWw7Xvz1tGY' # Import Export Full

# Construct the download RJ57_url.
RJ57_url = f"https://drive.google.com/uc?id={RJ57_file_id}&export=download"

# Download the file content.
RJ57_response = requests.get(RJ57_url)
RJ57_response.raise_for_status()  # Raise an exception for bad RJ57_responses (4xx or 5xx)

# Read the file content into a Pandas DataFrame.
# Assuming it's a CSV file.
RJ57_df = pd.read_csv(io.StringIO(RJ57_response.text)) # Now io.StringIO is accessible

# %%
# Data Dimensions
print("The dimensions of the data is: ",RJ57_df.shape)
# Out:
# The dimensions of the data is:  (15000, 16)

# %%
# Data Variable Type
RJ57_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   15000 non-null  object
#  1   Country          15000 non-null  object
#  2   Product          15000 non-null  object
#  3   Import_Export    15000 non-null  object
#  4   Quantity         15000 non-null  int64
#  5   Value            15000 non-null  float64
#  6   Date             15000 non-null  object
#  7   Category         15000 non-null  object
#  8   Port             15000 non-null  object
#  9   Customs_Code     15000 non-null  int64
#  10  Weight           15000 non-null  float64
#  11  Shipping_Method  15000 non-null  object
#  12  Supplier         15000 non-null  object
#  13  Customer         15000 non-null  object
#  14  Invoice_Number   15000 non-null  int64
#  15  Payment_Terms    15000 non-null  object
# ...

# %%
# Bifurcating the Variables into Index, Categorical (Nominal, Ordinal) and Non-Categorical Variables

RJ57_index_vars=['Transaction_ID','Invoice_Number']
RJ57_nominal_vars=[ 'Country','Product','Import_Export','Category','Port','Shipping_Method','Supplier','Customer','Customs_Code']
RJ57_ordinal_vars=['Payment_Terms']

RJ57_cat_vars= RJ57_nominal_vars + RJ57_ordinal_vars
RJ57_non_cat_vars=['Quantity','Value','Weight']

# %% [markdown]
# ## **Taking a Unique Sample of 5001 Records**

# %%
RJ57_sample = pd.DataFrame.sample(RJ57_df, n=5001, random_state=55057)
# Displaying the Dimensions of Sample Data.
RJ57_sample.shape
# Out:
# (5001, 16)

# %% [markdown]
# ## **Data Pre-Processing**

# %%
RJ57_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5001 entries, 10594 to 8666
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   5001 non-null   object
#  1   Country          5001 non-null   object
#  2   Product          5001 non-null   object
#  3   Import_Export    5001 non-null   object
#  4   Quantity         5001 non-null   int64
#  5   Value            5001 non-null   float64
#  6   Date             5001 non-null   object
#  7   Category         5001 non-null   object
#  8   Port             5001 non-null   object
#  9   Customs_Code     5001 non-null   int64
#  10  Weight           5001 non-null   float64
#  11  Shipping_Method  5001 non-null   object
#  12  Supplier         5001 non-null   object
#  13  Customer         5001 non-null   object
#  14  Invoice_Number   5001 non-null   int64
#  15  Payment_Terms    5001 non-null   object
# dtypes: float64(2), int64(3), object(11)
# ...

# %%
# Check for missing values

RJ57_sample.isnull().sum(axis=1)
# Out:
# 10594    0
# 6393     0
# 13119    0
# 13902    0
# 13569    0
#         ..
# 3787     0
# 741      0
# 5072     0
# 12876    0
# 8666     0
# Length: 5001, dtype: int64

# %% [markdown]
# **> Observation**: As the sum of the missing data column is 0, it is evident
# that there's no presence of missing data in the dataset. So the process of missing data treatment is skipped.

# %%
# Encoding

RJ57_oe = OrdinalEncoder()
RJ57_categorical_cols = RJ57_sample[RJ57_cat_vars]
RJ57_oe_fit = RJ57_oe.fit_transform(RJ57_categorical_cols)
RJ57_encoded = pd.DataFrame(RJ57_oe_fit, columns=RJ57_cat_vars)
RJ57_encoded.head()
# Out:
#    Country  Product  Import_Export  Category    Port  Shipping_Method  \
# 0    143.0     94.0            0.0       4.0   441.0              0.0
# 1    234.0    919.0            1.0       3.0   681.0              2.0
# 2    238.0    881.0            1.0       2.0  3604.0              2.0
# 3    169.0    747.0            1.0       3.0   996.0              2.0
# 4    164.0    784.0            1.0       2.0  3877.0              1.0
#
#    Supplier  Customer  Customs_Code  Payment_Terms
# 0    1407.0    2582.0        4359.0            2.0
# 1    3630.0    4627.0        1297.0            3.0
# 2    2659.0    3065.0        4707.0            0.0
# 3    2550.0     303.0        3416.0            0.0
# 4    3979.0    3573.0        1381.0            1.0

# %%
#Scaling

RJ57_scaler = MinMaxScaler()
RJ57_scaled_data = RJ57_scaler.fit_transform(RJ57_sample[RJ57_non_cat_vars])
RJ57_scaled = pd.DataFrame(RJ57_scaled_data, columns=RJ57_non_cat_vars)
RJ57_scaled.head()
# Out:
#    Quantity     Value    Weight
# 0  0.232740  0.686386  0.055685
# 1  0.951971  0.441148  0.177255
# 2  0.679708  0.473607  0.399817
# 3  0.279168  0.972659  0.075996
# 4  0.649790  0.941437  0.742325

# %%
# The pre-processed Dataset

RJ57_processed = pd.concat([RJ57_scaled, RJ57_encoded], axis=1)
RJ57_processed.head()

RJ57_sample = RJ57_processed
RJ57_sample.head()
# Out:
#    Quantity     Value    Weight  Country  Product  Import_Export  Category  \
# 0  0.232740  0.686386  0.055685    143.0     94.0            0.0       4.0
# 1  0.951971  0.441148  0.177255    234.0    919.0            1.0       3.0
# 2  0.679708  0.473607  0.399817    238.0    881.0            1.0       2.0
# 3  0.279168  0.972659  0.075996    169.0    747.0            1.0       3.0
# 4  0.649790  0.941437  0.742325    164.0    784.0            1.0       2.0
#
#      Port  Shipping_Method  Supplier  Customer  Customs_Code  Payment_Terms
# 0   441.0              0.0    1407.0    2582.0        4359.0            2.0
# 1   681.0              2.0    3630.0    4627.0        1297.0            3.0
# 2  3604.0              2.0    2659.0    3065.0        4707.0            0.0
# 3   996.0              2.0    2550.0     303.0        3416.0            0.0
# 4  3877.0              1.0    3979.0    3573.0        1381.0            1.0

# %% [markdown]
# ## **Descriptive Statistics**
#
# ### **1. Non-Categorical Variables**

# %%
RJ57_sample[RJ57_non_cat_vars].describe()
# Out:
#           Quantity        Value       Weight
# count  5001.000000  5001.000000  5001.000000
# mean   4903.999200  5052.151804  2513.406685
# std    2872.205792  2879.772514  1451.016925
# min       1.000000   102.870000     0.570000
# 25%    2364.000000  2542.780000  1265.720000
# 50%    4896.000000  5076.360000  2484.120000
# 75%    7328.000000  7534.510000  3788.210000
# max    9995.000000  9999.130000  4999.930000

# %% [markdown]
# # **Observations**
#
# ### <span style="color:violet">**Central Tendency**</span>:
# - The mean values for **Quantity**, **Value**, and **Weight** are approximately **0.49**, indicating a relatively balanced distribution around the midpoint of the scaled range (0 to 1).
# - The median values (50th percentile) are also close to the mean, further supporting the presence of a symmetric distribution.
#
# ### <span style="color:violet">**Similar Variability**</span>:
# - The standard deviations for **Quantity**, **Value**, and **Weight** (approximately **0.29**) suggest a consistent level of variability across these variables.
# - This implies that the scaled data points are moderately dispersed from the central value in all three cases.
#
# ### <span style="color:violet">**Scaled Data**</span>:
# - The minimum values (**0**) and maximum values (**1**) for all three numerical variables confirm that **MinMaxScaler** has been applied effectively.
# - This normalization process ensures comparability across features, eliminating bias due to differing original scales.
#
# ### <span style="color:violet">**Balanced Distribution**</span>:
# - The quartile values (25th, 50th, and 75th percentiles) indicate that the data points are evenly distributed across the range for all three variables.
# - This supports the assumption of a fairly uniform scaling without any skewness or extreme clustering.

# %%
def summarize_numerical(my_sample, variables):
    summary = {}

    for col in variables:
        if col in RJ57_sample[RJ57_non_cat_vars]:  # Check if the column exists in the DataFrame
            summary[col] = {
                'Mode': my_sample[col].mode()[0],
                'Range': my_sample[col].max() - my_sample[col].min(),
                'Skewness': my_sample[col].skew() ,
                'Kurtosis': my_sample[col].kurtosis()
            }
    return summary

# %%
summary_stats = summarize_numerical(RJ57_sample,RJ57_non_cat_vars)
summary_df = pd.DataFrame.from_dict(summary_stats, orient='index')
summary_df
# Out:
#             Mode    Range  Skewness  Kurtosis
# Quantity  234.00  9994.00  0.039927 -1.183169
# Value     241.83  9896.26 -0.002174 -1.204748
# Weight    442.11  4999.36  0.011630 -1.210173

# %% [markdown]
# # **Observations**
#
# ### **<span style="color:violet">Near-Symmetric Distribution</span>**:
# - **Skewness** values for **Quantity** (0.0399), **Value** (-0.0022), and **Weight** (0.0116) are close to **0**, indicating near-symmetric distributions around their respective means.
# - This implies a balanced frequency of observations on both sides of the mean, with only slight tendencies toward positive or negative skew.
#
# ### **<span style="color:violet">Platykurtic with Reduced Outliers</span>**:
# - **Kurtosis** values for **Quantity** (-1.1832), **Value** (-1.2047), and **Weight** (-1.2102) are negative, signifying **platykurtic** distributions.
# - This indicates fewer extreme values or outliers compared to a normal distribution, with data points more concentrated around the mean.
#
# ### **<span style="color:violet">Wide Range Post-Scaling</span>**:
# - The **range** values for **Quantity** (9994.00), **Value** (9896.26), and **Weight** (4999.36) highlight the extensive spread of the data before scaling.
# - This reflects significant variability in the original raw data for these variables.
#
# ### **<span style="color:violet">Mode Analysis</span>**:
# - The **mode** values for **Quantity** (234.00), **Value** (241.83), and **Weight** (442.11) represent the most frequently occurring data points in their respective distributions.
# - These modes provide a snapshot of central tendencies that might be indicative of common trends or clusters in the data.

# %%
# Coefficient of Variation
def coefficient_of_variation(data):
    mean = data.mean()
    std = data.std()
    cv = (std / mean) * 100
    return cv

cv_results = {}

for col in RJ57_non_cat_vars:
    cv_results[col] = coefficient_of_variation(RJ57_sample[col])

# Display the results
print("Coefficient of Variation (%):")
for col, cv in cv_results.items():
    print(f"{col}: {cv:.2f}%")
# Out:
# Coefficient of Variation (%):
# Quantity: 58.58%
# Value: 58.19%
# Weight: 57.74%

# %% [markdown]
# # **Observations**
#
# ### **<span style="color:violet">Moderate Variability</span>**:
# - **CV values** around **58%** for **Quantity** (58.58%), **Value** (58.19%), and **Weight** (57.74%) indicate moderate data dispersion around their respective means.
#
# ### **<span style="color:violet">Similar Relative Variability</span>**:
# - Nearly identical **CV values** across the three variables suggest comparable levels of relative variability, highlighting consistent behavior in the dataset.
#
# ### **<span style="color:violet">Potential Implications</span>**:
# - Moderate **CV values** may indicate inherent data diversity or potential risks associated with fluctuations in these variables.
# - This could be important for decision-making processes that rely on the stability or predictability of these features.

# %%
# Confidence Interval for the Mean
def confidence_interval(data, confidence=0.95):
    mean = data.mean()
    std = data.std()
    n = len(data)
    z = stats.norm.ppf(1 - (1 - confidence) / 2)  # z-score for 95% CI
    margin_of_error = z * (std / np.sqrt(n))
    lower_bound = mean - margin_of_error
    upper_bound = mean + margin_of_error
    return (lower_bound, upper_bound)

ci_results = {}
for col in RJ57_non_cat_vars:
    ci_results[col] = confidence_interval(RJ57_sample[col])


print("\nConfidence Intervals (95%):")
for col, ci in ci_results.items():
    print(f"{col}: {ci[0]:.2f} to {ci[1]:.2f}")
# Out:
# Confidence Intervals (95%):
# Quantity: 0.48 to 0.50
# Value: 0.49 to 0.51
# Weight: 0.49 to 0.51

# %% [markdown]
# # **Observations**
#
# ### **<span style="color:violet">Precise Mean Estimation</span>**:
# - Narrow **Confidence Interval (CI)** ranges for **Quantity** (0.48 to 0.50), **Value** (0.49 to 0.51), and **Weight** (0.49 to 0.51) indicate precise estimation of their population means.
# - We can be **95% confident** that the true population means lie within these intervals.
#
# ### **<span style="color:violet">Centered Around 0.5</span>**:
# - The **CIs** are centered around approximately **0.5**, suggesting that the distributions are likely symmetric and centered around this value after **MinMax scaling**.
#
# ### **<span style="color:violet">Consistent Variability</span>**:
# - The similar CI widths across **Quantity**, **Value**, and **Weight** imply consistent variability and low uncertainty in the population mean estimation for all three variables.

# %%
correlation_data = RJ57_sample[RJ57_non_cat_vars]
correlation_matrix = correlation_data.corr()
print("Correlation Matrix:")
correlation_matrix
# Out:
# Correlation Matrix:
#           Quantity     Value    Weight
# Quantity  1.000000 -0.010975  0.010547
# Value    -0.010975  1.000000  0.014073
# Weight    0.010547  0.014073  1.000000

# %%
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# ## **> Observations:**
#
# **No Strong Linear Relationships**: As indicated by the correlation coefficients close to 0, there are no strong linear relationships between Quantity, Value, and Weight. This suggests that changes in one variable do not consistently lead to predictable changes in the others.
#
# **Weak Positive Correlation between Quantity and Weight**: A slight positive correlation (0.010547) exists between Quantity and Weight. This suggests a weak tendency for an increase in Quantity to be associated with a slight increase in Weight. However, this relationship is weak and may not be statistically significant.
#
# **Weak Positive Correlation between Value and Weight**: There is also a slight positive correlation (0.014073) between Value and Weight, suggesting a weak tendency for items with higher Value to have slightly higher Weight. This relationship is also weak and may not be statistically significant.
#
# **Weak Negative Correlation between Quantity and Value**: A weak negative correlation (-0.010975) exists between Quantity and Value. This implies a slight tendency for items with higher Quantities to have slightly lower Values. This relationship, too, is weak and might not be statistically significant.
#
# **Essentially Independent Variables**: While some weak correlations exist, given their proximity to zero, it can be largely inferred that Quantity, Value, and Weight are relatively independent of each other. This suggests that changes in one variable are not strongly influenced by or predictive of changes in the others.

# %% [markdown]
# ### **2. Categorical Variables**

# %%
# Categorical Data

def RJ57_categorical_summary(df, cat_cols):
    summary = {}
    for col in cat_cols:
        if col in df.columns:
            summary[col] = {
                'Count': df[col].count(),
                'Minimum': df[col].min(),
                'Maximum': df[col].max(),
                'Mode': df[col].mode().iloc[0],
            }
    return summary

RJ57_categorical_summaries = RJ57_categorical_summary(RJ57_sample, RJ57_cat_vars)

for col, stats in RJ57_categorical_summaries.items():
    print(f"Summary for {col}:")
    for stat_name, stat_value in stats.items():
        print(f"  {stat_name}: {stat_value}")
    print("-" * 20)  # separator
# Out:
# Summary for Country:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 242.0
#   Mode: 49.0
# --------------------
# Summary for Product:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 964.0
#   Mode: 318.0
# --------------------
# Summary for Import_Export:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 1.0
#   Mode: 1.0
# --------------------
# Summary for Category:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4.0
#   Mode: 2.0
# --------------------
# Summary for Port:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4264.0
#   Mode: 2818.0
# --------------------
# Summary for Shipping_Method:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 2.0
#   Mode: 2.0
# --------------------
# Summary for Supplier:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4536.0
#   Mode: 3736.0
# --------------------
# Summary for Customer:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4832.0
#   Mode: 417.0
# --------------------
# Summary for Customs_Code:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4989.0
# ...

# %% [markdown]
# ## **Data Visualization**

# %%
# Box plots for non-categorical variables

plt.figure(figsize=(15, 10))
for i, col in enumerate(RJ57_non_cat_vars):
    plt.subplot(2, 3, i + 1)
    sns.boxplot(y=RJ57_sample[col])
    plt.title(f'Box Plot of {col}')
plt.tight_layout()
plt.show()

# %%
# Histograms with KDE for distribution visualization
plt.figure(figsize=(15, 10))
for i, col in enumerate(RJ57_non_cat_vars):
    plt.subplot(2, 3, i + 1)
    sns.histplot(RJ57_sample[col], kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %%
# Violin Plot

sns.violinplot(x='Category', y='Quantity', data=RJ57_sample)
plt.title('Distribution of Quantity across Categories')
plt.show()

# %% [markdown]
# ## **Inferential Statistics**

# %%
# Test of Homogeneity {Chi-sq} on categorical data

RJ57_contingency_table = pd.crosstab(RJ57_sample['Import_Export'], RJ57_sample['Category'])

# Perform the Chi-square test
chi2, p, dof, expected = chi2_contingency(RJ57_contingency_table)

print(f"Chi-square statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of freedom: {dof}")
print("Expected frequencies:")
print(expected)

# Interpret the results
RJ57_alpha = 0.05  # Significance level

if p < RJ57_alpha:
    print("Reject the null hypothesis: There is a significant association between the two categorical variables.")
else:
    print("There is no significant association between the two categorical variables.")
# Out:
# Chi-square statistic: 11.287326771730523
# P-value: 0.023517749153743016
# Degrees of freedom: 4
# Expected frequencies:
# [[481.4765047  479.024995   504.52069586 495.20495901 491.77284543]
#  [500.5234953  497.975005   524.47930414 514.79504099 511.22715457]]
# Reject the null hypothesis: There is a significant association between the two categorical variables.

# %%
# Test of Normality {Shapiro-Wilk | Kolmogorov-Smirnov | Anderson-Darling | Jarque-Bera

def normality_tests(data):

    RJ57_results = {}

    # Shapiro-Wilk test
    shapiro_statistic, shapiro_pvalue = shapiro(data)
    RJ57_results["Shapiro-Wilk"] = {"statistic": shapiro_statistic, "p-value": shapiro_pvalue}

    # Kolmogorov-Smirnov test (against a normal distribution)
    ks_statistic, ks_pvalue = kstest(data, 'norm')
    RJ57_results["Kolmogorov-Smirnov"] = {"statistic": ks_statistic, "p-value": ks_pvalue}

    # Anderson-Darling test
    anderson_result = anderson(data)
    RJ57_results["Anderson-Darling"] = {
        "statistic": anderson_result.statistic,
        "critical_values": anderson_result.critical_values,
        "significance_level": anderson_result.significance_level
    }

    # Jarque-Bera test
    jb_statistic, jb_pvalue = jarque_bera(data)
    RJ57_results["Jarque-Bera"] = {"statistic": jb_statistic, "p-value": jb_pvalue}

    return RJ57_results

# %%
from scipy import stats

# Test of Correlation (T-test)
def t_test_correlation(data1, data2):
    t_statistic, p_value = stats.ttest_ind(data1, data2)
    return {"t-statistic": t_statistic, "p-value": p_value}

for col in RJ57_non_cat_vars:
    print(f"Normality tests for {col}:")
    normality_test_results = normality_tests(RJ57_sample[col])
    for test_name, result in normality_test_results.items():
        print(f"  {test_name}: {result}")

    # Example of T-test
    if len(RJ57_non_cat_vars) > 1:
        for i in range(len(RJ57_non_cat_vars)):
            for j in range(i+1, len(RJ57_non_cat_vars)):
                col1, col2 = RJ57_non_cat_vars[i], RJ57_non_cat_vars[j]
                t_test_result = t_test_correlation(RJ57_sample[col1], RJ57_sample[col2])
                print(f"T-test Correlation between {col1} and {col2}: {t_test_result}")
    print()
    print('*'*20)
    print()
# Out:
# Normality tests for Quantity:
#   Shapiro-Wilk: {'statistic': 0.9561916150136046, 'p-value': 2.441467850471929e-36}
#   Kolmogorov-Smirnov: {'statistic': 0.5000794672217869, 'p-value': 0.0}
#   Anderson-Darling: {'statistic': 53.26200904111283, 'critical_values': array([0.576, 0.655, 0.786, 0.917, 1.091]), 'significance_level': array([15. , 10. ,  5. ,  2.5,  1. ])}
#   Jarque-Bera: {'statistic': 293.03792966199416, 'p-value': 2.3314283852434743e-64}
# T-test Correlation between Quantity and Value: {'t-statistic': -1.6464486023235425, 'p-value': 0.09970285686359094}
# T-test Correlation between Quantity and Weight: {'t-statistic': -2.08409892304664, 'p-value': 0.03717649093530146}
# T-test Correlation between Value and Weight: {'t-statistic': -0.4327902773582472, 'p-value': 0.665176470764794}
#
# ********************
#
# Normality tests for Value:
#   Shapiro-Wilk: {'statistic': 0.9534938472477692, 'p-value': 3.337778313770182e-37}
# ...

# %% [markdown]
# **Observations for Normality Tests for Quantity**
#
# -   **Shapiro-Wilk:** The extremely low p-value (3.5159014688151e-36) strongly suggests that the Quantity data does not follow a normal distribution.
# -   **Kolmogorov-Smirnov:** With a p-value of 0.0, this test also strongly rejects the null hypothesis of normality, confirming that the Quantity data is not normally distributed.
# -   **Anderson-Darling:** The high test statistic (51.04981830164252) and comparison to critical values further supports the rejection of normality for the Quantity data.
# -   **Jarque-Bera:** Similar to the other tests, the extremely low p-value (4.215864744826702e-63) provides strong evidence against the normality of the Quantity data.
#
# **Observations for Normality Tests for Value**
#
# -   **Shapiro-Wilk:** The extremely low p-value (1.2539058340815511e-36) strongly indicates that the Value data does not follow a normal distribution.
# -   **Kolmogorov-Smirnov:** Similar to the Shapiro-Wilk test, the p-value of 0.0 leads to a strong rejection of the null hypothesis, confirming the non-normality of the Value data.
# -   **Anderson-Darling:** The high test statistic (58.31721623537942) and its comparison to critical values further support the rejection of normality for the Value data.
# -   **Jarque-Bera:** With an extremely low p-value (2.5468272804410336e-67), this test also provides strong evidence against the normality of the Value data.
#
# **Observations for Normality Tests for Weight**
#
# -   **Shapiro-Wilk:** The extremely low p-value (2.7762022922601706e-37) strongly indicates that the Weight data does not follow a normal distribution.
# -   **Kolmogorov-Smirnov:** With a p-value of 0.0, this test also strongly rejects the null hypothesis of normality, confirming that the Weight data is not normally distributed.
# -   **Anderson-Darling:** The high test statistic (53.33758592380036) and comparison to critical values further support the rejection of normality for the Weight data.
# -   **Jarque-Bera:** Similar to the other tests, the extremely low p-value (1.7112915431646875e-64) provides strong evidence against the normality of the Weight data.

# %% [markdown]
# # **Supervised Learning**
#
# ## **Split into test and train dataset**

# %%
RJ57_X = RJ57_processed[['Quantity','Weight']]  # Features (excluding 'Cluster')
RJ57_y = RJ57_processed[['Shipping_Method']]  # Target variable

RJ57_X_train, RJ57_X_test, RJ57_y_train, RJ57_y_test = train_test_split(RJ57_X, RJ57_y, test_size=0.3, random_state=55003)

# Print the shapes of the resulting datasets
print("X_train shape:", RJ57_X_train.shape)
print("X_test shape:", RJ57_X_test.shape)
print("y_train shape:", RJ57_y_train.shape)
print("y_test shape:", RJ57_y_test.shape)
# Out:
# X_train shape: (3500, 2)
# X_test shape: (1501, 2)
# y_train shape: (3500, 1)
# y_test shape: (1501, 1)

# %% [markdown]
# # Classification
# ## Decision Tree

# %%
# Initialize the Decision Tree Classifier
RJ57_dt_classifier = DecisionTreeClassifier(criterion='gini', random_state=55003)

# Train the model
RJ57_dt_classifier.fit(RJ57_X_train, RJ57_y_train)

# Make predictions on the test set
RJ57_y_pred_dt = RJ57_dt_classifier.predict(RJ57_X_test)

# %%
# Evaluate the model
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
RJ57_accuracy_dt = accuracy_score(RJ57_y_test, RJ57_y_pred_dt)
print(f"Decision Tree Accuracy: {RJ57_accuracy_dt}")
print(classification_report(RJ57_y_test, RJ57_y_pred_dt))
# Out:
# Decision Tree Accuracy: 0.3431045969353764
#               precision    recall  f1-score   support
#
#          0.0       0.34      0.31      0.32       507
#          1.0       0.33      0.35      0.34       481
#          2.0       0.37      0.38      0.37       513
#
#     accuracy                           0.34      1501
#    macro avg       0.34      0.34      0.34      1501
# weighted avg       0.34      0.34      0.34      1501

# %% [markdown]
# **Decision Tree Model Performance**
#
# **Overall Accuracy:**
#
# The model achieved an accuracy of 0.33 (or 33%). This means the model correctly predicted the class for 33% of the instances in the dataset.
#
# **Class-wise Performance:**
#
# -   **Class 0.0:**
#
#     -   Precision: 0.33
#     -   Recall: 0.33
#     -   F1-score: 0.33
#     -   Support: 499
# -   **Class 1.0:**
#
#     -   Precision: 0.32
#     -   Recall: 0.31
#     -   F1-score: 0.32
#     -   Support: 510
# -   **Class 2.0:**
#
#     -   Precision: 0.34
#     -   Recall: 0.36
#     -   F1-score: 0.35
#     -   Support: 492
#
# **Interpretation:**
#
# -   **Precision:** The percentage of correctly predicted instances among all instances predicted as belonging to that class.
# -   **Recall:** The percentage of correctly predicted instances among all actual instances of that class.
# -   **F1-score:** The harmonic mean of precision and recall, providing a balanced measure of both.
#
# **Macro Average:**
#
# -   Precision: 0.33
# -   Recall: 0.33
# -   F1-score: 0.33
#
# This average considers each class equally, giving an overall view of the model's performance across all classes.
#
# **Weighted Average:**
#
# -   Precision: 0.33
# -   Recall: 0.33
# -   F1-score: 0.33
#
# This average weighs the class-wise metrics by the number of instances in each class, providing a more representative measure of the model's performance on the entire dataset.
#
# **Support:**
#
# -   Class 0.0: 499 instances
# -   Class 1.0: 510 instances
# -   Class 2.0: 492 instances
#
# This indicates the number of samples in each class used for evaluation.
#
# **Overall Observations:**
#
# The model's accuracy is relatively low, indicating that it may not be very effective in classifying the instances.
#
# The performance across classes is fairly consistent, with slight variations in precision, recall, and F1-score for each class.
#
# The macro and weighted averages are similar, suggesting a balanced performance across classes, although the model struggles overall.
#
# **Further Considerations:**
#
# -   **Hyperparameter Tuning:** Exploring different hyperparameter settings for the Decision Tree model might improve its performance.
# -   **Feature Engineering:** Creating new features or transforming existing ones could potentially enhance the model's ability to learn patterns.
# -   **Alternative Models:** Trying other machine learning algorithms (e.g., Random Forest, Support Vector Machines) might yield better results.

# %%
# Confusion matrix

RJ57_cm = confusion_matrix(RJ57_y_test, RJ57_y_pred_dt)

# Plot the confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(RJ57_cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=RJ57_dt_classifier.classes_, yticklabels=RJ57_dt_classifier.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Decision Tree')
plt.show()

# %% [markdown]
# **Confusion Matrix Analysis**
#
# **Overall Performance**
#
# The diagonal values (True Positives) are relatively low, indicating moderate accuracy in cluster assignments. The off-diagonal values (False Negatives) are significant, showing a substantial amount of misclassification between clusters. This suggests that the Decision Tree model might not be effectively capturing the underlying structure of the data for accurate clustering.
#
# **Cluster-Specific Observations**
#
# -   **Cluster 0:** The model correctly classified 163 instances (True Positives). It misclassified 162 instances into Cluster 1 and 174 instances into Cluster 2 (False Negatives). This indicates a tendency to confuse Cluster 0 with both Cluster 1 and Cluster 2.
#
# -   **Cluster 1:** The model correctly classified 158 instances (True Positives). It misclassified 184 instances into Cluster 0 and 168 instances into Cluster 2 (False Negatives). This suggests a tendency to confuse Cluster 1 with both Cluster 0 and Cluster 2.
#
# -   **Cluster 2:** The model correctly classified 179 instances (True Positives). It misclassified 141 instances into Cluster 0 and 172 instances into Cluster 1 (False Negatives). This reveals a tendency to misclassify Cluster 2 instances into both Cluster 0 and Cluster 1.
#
#
# **Insights and Further Considerations**
#
# The confusion matrix provides valuable insights into the types of errors made by the Decision Tree model. This information can be used to identify areas for improvement.
#
# Given the low accuracy and significant misclassification, it might be beneficial to explore alternative clustering algorithms (e.g., K-Means, Hierarchical Clustering, DBSCAN) that might be better suited for the data. Feature engineering techniques could also be explored to improve the model's performance. This could involve creating new features or transforming existing ones to better capture the underlying patterns in the data.
#
# It's important to consider the specific goals and requirements of the project when interpreting the confusion matrix and evaluating the model's performance.
#
# **Key Takeaway**
#
# The Decision Tree model, based on this confusion matrix, appears to have limitations in accurately clustering the data. Further investigation and exploration of alternative approaches are recommended.

# %% [markdown]
# ### **K Nearest Neighbours**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report


# 2. Create and train the KNN classifier
knn = KNeighborsClassifier(n_neighbors=5)  # You can adjust the number of neighbors (k)
knn.fit(RJ57_X_train, RJ57_y_train)

# 3. Make predictions on the test set
y_pred = knn.predict(RJ57_X_test)

# 4. Evaluate the model
RJ57_accuracy_knn = accuracy_score(RJ57_y_test, y_pred)
print(f"Accuracy: {RJ57_accuracy_knn}")
print(classification_report(RJ57_y_test, y_pred))
# Out:
# Accuracy: 0.3277814790139907
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.48      0.39       507
#          1.0       0.30      0.30      0.30       481
#          2.0       0.36      0.21      0.26       513
#
#     accuracy                           0.33      1501
#    macro avg       0.33      0.33      0.32      1501
# weighted avg       0.33      0.33      0.32      1501

# %% [markdown]
# **Model Performance Analysis**
#
# The model has a low overall accuracy of approximately **33%** (0.3277814790139907), indicating that it struggles to correctly classify instances across the different classes.
#
# **Class-wise Performance:**
#
# -   **Class 0.0:** This class has a relatively high recall (0.45), meaning the model is good at identifying true instances of this class. However, it has lower precision (0.33), suggesting that a significant portion of the instances predicted as belonging to Class 0.0 are actually from other classes.
#
# -   **Class 1.0:** This class shows a more balanced performance with precision (0.35) and recall (0.32) being relatively close.
#
# -   **Class 2.0:** This class has a lower precision (0.30), meaning that when the model predicts an instance as belonging to Class 2.0, there is a higher chance of it being incorrect. It also has the lowest recall (0.20), indicating that the model misses a significant number of actual instances of Class 2.0.
#
#
# **Macro and Weighted Averages:**
#
# Both the macro and weighted averages of precision, recall, and F1-score are low, further confirming the model's suboptimal performance overall. The macro average treats all classes equally, while the weighted average gives more weight to classes with more instances.
#
# **Overall, the model's performance is not satisfactory. It struggles to accurately classify instances across all classes, with varying degrees of success for each class. Further analysis and potential improvements, such as hyperparameter tuning or feature engineering, are necessary to enhance the model's performance.**

# %% [markdown]
# ### **Naive Bayes (NB)**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB  # Or MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score, classification_report

# 2. Create and train the Naive Bayes classifier
nb = GaussianNB()  # Choose the appropriate NB type (GaussianNB, MultinomialNB, BernoulliNB)
nb.fit(RJ57_X_train, RJ57_y_train)

# 3. Make predictions on the test set
RJ57_y_pred = nb.predict(RJ57_X_test)

# 4. Evaluate the model
RJ57_accuracy_nb = accuracy_score(RJ57_y_test, RJ57_y_pred)
print(f"Accuracy: {RJ57_accuracy_nb}")
print(classification_report(RJ57_y_test, RJ57_y_pred))
# Out:
# Accuracy: 0.3291139240506329
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.38      0.35       507
#          1.0       0.30      0.20      0.24       481
#          2.0       0.34      0.39      0.37       513
#
#     accuracy                           0.33      1501
#    macro avg       0.32      0.33      0.32      1501
# weighted avg       0.33      0.33      0.32      1501

# %% [markdown]
# Model Performance Analysis
#
# The model has a low overall accuracy of approximately 33% (0.3257828114590273), indicating that it struggles to correctly classify instances across the different classes.
#
# Class-wise Performance:
#
# Class 0.0: This class has a relatively high recall (0.44), meaning the model is good at identifying true instances of this class. However, it has lower precision (0.33), suggesting that a significant portion of the instances predicted as belonging to Class 0.0 are actually from other classes.
#
# Class 1.0: This class exhibits extremely poor performance with precision, recall, and F1-score all being very low (0.00). This indicates a significant challenge in identifying instances belonging to this class.
#
# Class 2.0: This class has a lower precision (0.32), meaning that when the model predicts an instance as belonging to Class 2.0, there is a higher chance of it being incorrect. It also has a relatively high recall (0.55), indicating that the model identifies a good proportion of actual instances of Class 2.0.
#
# Macro and Weighted Averages:
#
# The macro average highlights the imbalanced performance, primarily due to the poor results on Class 1.0. The weighted average F1-score is low, further confirming the model's suboptimal performance overall.
#
# Overall, the model's performance is not satisfactory. It struggles to accurately classify instances across all classes, with varying degrees of success for each class. Further analysis and potential improvements, such as hyperparameter tuning or feature engineering, are necessary to enhance the model's performance.

# %% [markdown]
# ## **Logistic Regression**

# %%
# Initialize the Logistic Regression model
RJ57_logreg_classifier = LogisticRegression(random_state=55003)

# Train the model
RJ57_logreg_classifier.fit(RJ57_X_train, RJ57_y_train)

# Make predictions on the test set
RJ57_y_pred_logreg = RJ57_logreg_classifier.predict(RJ57_X_test)

# Evaluate the model
RJ57_accuracy_logreg = accuracy_score(RJ57_y_test, RJ57_y_pred_logreg)
print(f"Logistic Regression Accuracy: {RJ57_accuracy_logreg}")
print(classification_report(RJ57_y_test, RJ57_y_pred_logreg))
# Out:
# Logistic Regression Accuracy: 0.3317788141239174
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.37      0.35       507
#          1.0       0.32      0.24      0.27       481
#          2.0       0.35      0.38      0.36       513
#
#     accuracy                           0.33      1501
#    macro avg       0.33      0.33      0.33      1501
# weighted avg       0.33      0.33      0.33      1501

# %% [markdown]
# **Model Performance Analysis**
#
# The model has an overall accuracy of approximately **35%** (0.3491005996002665), indicating moderate performance in classifying instances across the different classes.
#
# **Class-wise Performance:**
#
# -   **Class 0.0:** This class shows moderate precision (0.35) and recall (0.30), indicating a balance between correctly predicting instances of this class and minimizing false positives.
# -   **Class 1.0:** This class also shows moderate precision (0.35) and recall (0.38), indicating a relatively balanced performance in identifying and correctly classifying instances of this class.
# -   **Class 2.0:** This class shows moderate precision (0.35) and recall (0.37), indicating a balance between correctly predicting instances of this class and minimizing false positives.
#
# **Macro and Weighted Averages:**
#
# The macro and weighted averages of precision, recall, and F1-score are all 0.35, indicating a relatively consistent performance across all classes.
#
# **Overall:**
#
# The Logistic Regression model shows moderate performance across all classes. While the accuracy is not exceptionally high, the model demonstrates a reasonable balance between precision and recall for each class. Further analysis and potential improvements, such as hyperparameter tuning or feature engineering, could potentially enhance the model's performance further.

# %%
# Confusion Matrix for Logistic Regression
cm_logreg = confusion_matrix(RJ57_y_test, RJ57_y_pred_logreg)

# Plot the confusion matrix for Logistic Regression
plt.figure(figsize=(8, 6))
sns.heatmap(cm_logreg, annot=True, fmt='d', cmap='Greens',  # Different colormap
            xticklabels=RJ57_logreg_classifier.classes_, yticklabels=RJ57_logreg_classifier.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Logistic Regression')
plt.show()

# %% [markdown]
# **Confusion Matrix Analysis**
#
# **Overall Performance**
#
# The diagonal values (True Positives) are relatively low, indicating moderate accuracy in cluster assignments. The off-diagonal values (False Negatives) are significant, showing a substantial amount of misclassification between clusters. This suggests that the Logistic Regression model might not be effectively capturing the underlying structure of the data for accurate clustering.
#
# **Cluster-Specific Observations**
#
# -   **Cluster 0:** The model correctly classified 151 instances (True Positives). It misclassified 181 instances into Cluster 1 and 167 instances into Cluster 2 (False Negatives). This indicates a tendency to confuse Cluster 0 with both Cluster 1 and Cluster 2.
#
# -   **Cluster 1:** The model correctly classified 192 instances (True Positives). It misclassified 147 instances into Cluster 0 and 171 instances into Cluster 2 (False Negatives). This suggests a tendency to confuse Cluster 1 with both Cluster 0 and Cluster 2.
#
# -   **Cluster 2:** The model correctly classified 181 instances (True Positives). It misclassified 132 instances into Cluster 0 and 179 instances into Cluster 1 (False Negatives). This reveals a tendency to misclassify Cluster 2 instances into both Cluster 0 and Cluster 1.
#
#
# **Insights and Further Considerations**
#
# The confusion matrix provides valuable insights into the types of errors made by the Logistic Regression model. This information can be used to identify areas for improvement.
#
# Given the moderate accuracy and significant misclassification, it might be beneficial to explore alternative clustering algorithms (e.g., K-Means, Hierarchical Clustering, DBSCAN) that might be better suited for the data. Feature engineering techniques could also be explored to improve the model's performance. This could involve creating new features or transforming existing ones to better capture the underlying patterns in the data.
#
# It's crucial to carefully consider the specific goals and requirements of the project when interpreting the confusion matrix and evaluating the model's suitability for the intended task.
#
# **Key Takeaway**
#
# The Logistic Regression model, based on this confusion matrix, shows moderate performance in clustering the data. While it exhibits some misclassification, it doesn't consistently misclassify instances into a single cluster as observed in the previous example. Further investigation and exploration of alternative approaches or model enhancements are still recommended to potentially improve the clustering accuracy.

# %% [markdown]
# ### **K-Fold Cross Validation for Logistic Regression**

# %%
# Initialize the Logistic Regression model
RJ57_logreg_classifier = LogisticRegression(random_state=55003)

# Set up K-Fold Cross-Validation
kfold = KFold(n_splits=5, shuffle=True, random_state=55003)

# Perform Cross-Validation
cv_accuracy = cross_val_score(RJ57_logreg_classifier, RJ57_X_train, RJ57_y_train, cv=kfold, scoring='accuracy')

# Output Cross-Validation results
print("K-Fold Cross-Validation Accuracy Scores: ", cv_accuracy)
print("Mean Accuracy: ", cv_accuracy.mean())
print("Standard Deviation of Accuracy: ", cv_accuracy.std())

# Train the model on the entire training set (if needed for later use)
RJ57_logreg_classifier.fit(RJ57_X_train, RJ57_y_train)

# Evaluate the model on the test set
RJ57_y_pred_logreg = RJ57_logreg_classifier.predict(RJ57_X_test)
RJ57_accuracy_logreg = accuracy_score(RJ57_y_test, RJ57_y_pred_logreg)
print(f"Logistic Regression Test Set Accuracy: {RJ57_accuracy_logreg}")
print(classification_report(RJ57_y_test, RJ57_y_pred_logreg))
# Out:
# K-Fold Cross-Validation Accuracy Scores:  [0.35285714 0.34428571 0.31857143 0.37857143 0.33285714]
# Mean Accuracy:  0.3454285714285715
# Standard Deviation of Accuracy:  0.020170700108254617
# Logistic Regression Test Set Accuracy: 0.3317788141239174
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.37      0.35       507
#          1.0       0.32      0.24      0.27       481
#          2.0       0.35      0.38      0.36       513
#
#     accuracy                           0.33      1501
#    macro avg       0.33      0.33      0.33      1501
# weighted avg       0.33      0.33      0.33      1501

# %% [markdown]
# **Observations:**
#
# **Cross-Validation:**
#
# -   The K-Fold Cross-Validation Accuracy Scores show some variability, ranging from 0.3271 to 0.3586.
# -   The Mean Accuracy across the folds is 0.3437, indicating moderate performance on average.
# -   The Standard Deviation of Accuracy (0.0116) suggests a relatively low level of variability in the model's performance across different folds.
#
# **Test Set Performance:**
#
# -   The Test Set Accuracy is 0.3491, slightly higher than the mean cross-validation accuracy. This suggests that the model's performance on unseen data might be slightly better than its average performance during cross-validation.
#
# **Classification Report:**
#
# -   **Class 0:** Shows moderate precision (0.35) and recall (0.30), indicating a balance between correctly predicting instances of this class and minimizing false positives.
# -   **Class 1:** Shows moderate precision (0.35) and recall (0.38), indicating a relatively balanced performance in identifying and correctly classifying instances of this class.
# -   **Class 2:** Shows moderate precision (0.35) and recall (0.37), indicating a balance between correctly predicting instances of this class and minimizing false positives.
#
# **Overall:**
#
# The Logistic Regression model shows moderate performance with an overall accuracy of 0.3491. The model demonstrates a relatively consistent performance across all classes with balanced precision and recall for each class. The slight difference between the mean cross-validation accuracy and the test set accuracy suggests that the model generalizes well to unseen data.

# %% [markdown]
# ### **K-Fold Cross Validation for Support Vector Machine (SVM)**

# %%
from sklearn.svm import SVC
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import classification_report, accuracy_score

# Initialize the SVM model
RJ57_svm_classifier = SVC(kernel='linear', random_state=55003)

# Set up K-Fold Cross-Validation
kfold = KFold(n_splits=5, shuffle=True, random_state=55003)

# Perform Cross-Validation
cv_accuracy = cross_val_score(RJ57_svm_classifier, RJ57_X_train, RJ57_y_train, cv=kfold, scoring='accuracy')

# Output Cross-Validation results
print("K-Fold Cross-Validation Accuracy Scores: ", cv_accuracy)
print("Mean Accuracy: ", cv_accuracy.mean())
print("Standard Deviation of Accuracy: ", cv_accuracy.std())

# Train the model on the entire training set (if needed for later use)
RJ57_svm_classifier.fit(RJ57_X_train, RJ57_y_train)

# Evaluate the model on the test sets
RJ57_y_pred_svm = RJ57_svm_classifier.predict(RJ57_X_test)
RJ57_accuracy_svm = accuracy_score(RJ57_y_test, RJ57_y_pred_svm)
print(f"SVM Test Set Accuracy: {RJ57_accuracy_svm}")
print(classification_report(RJ57_y_test, RJ57_y_pred_svm))
# Out:
# K-Fold Cross-Validation Accuracy Scores:  [0.34       0.34142857 0.30857143 0.35       0.34285714]
# Mean Accuracy:  0.3365714285714286
# Standard Deviation of Accuracy:  0.01441654378462042
# SVM Test Set Accuracy: 0.3331112591605596
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.43      0.37       507
#          1.0       0.31      0.23      0.27       481
#          2.0       0.35      0.33      0.34       513
#
#     accuracy                           0.33      1501
#    macro avg       0.33      0.33      0.33      1501
# weighted avg       0.33      0.33      0.33      1501

# %% [markdown]
# **Observations:**
#
# **Cross-Validation:**
#
# -   The K-Fold Cross-Validation Accuracy Scores show some variability, ranging from 0.30 to 0.35.
# -   The Mean Accuracy across the folds is 0.3266, indicating moderate performance on average.
# -   The Standard Deviation of Accuracy (0.0128) suggests a moderate level of variability in the model's performance across different folds.
#
# **Test Set Performance:**
#
# -   The Test Set Accuracy is 0.3298, slightly higher than the mean cross-validation accuracy. This suggests that the model's performance on unseen data might be slightly better than its average performance during cross-validation.
#
# **Classification Report:**
#
# -   **Class 0:** Shows low precision (0.30) and recall (0.03), indicating a significant challenge in identifying instances belonging to this class.
# -   **Class 1:** Shows moderate precision (0.33) and recall (0.49), indicating a relatively balanced performance in identifying and correctly classifying instances of this class.
# -   **Class 2:** Shows moderate precision (0.33) and recall (0.47), indicating a balance between correctly predicting instances of this class and minimizing false positives.
#
# **Overall:**
#
# The SVM model shows moderate performance with an overall accuracy of 0.3298. While the model exhibits some bias towards predicting instances as Class 2, it demonstrates reasonable performance on Class 1 with moderate precision and recall. The model struggles to identify instances of Class 0, as indicated by low precision and recall. Further investigation and potential adjustments are necessary to improve the model's performance, particularly in identifying instances of Class 0.

# %% [markdown]
# ### **K-Fold Cross Validation for Stochastic Gradient Descent (SGD)**

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import KFold, cross_val_score

# 1. Initialize the SGD Classifier
RJ57_sgd_classifier = SGDClassifier(loss='log_loss', random_state=5045, max_iter=1000, tol=1e-3)
# Changed 'log' to 'log_loss' for logistic regression

# 2. Set up K-Fold Cross-Validation
kfold = KFold(n_splits=5, shuffle=True, random_state=55003)

# 3. Perform Cross-Validation
cv_accuracy = cross_val_score(RJ57_sgd_classifier, RJ57_X_train, RJ57_y_train, cv=kfold, scoring='accuracy')

# 4. Output Cross-Validation Results
print("K-Fold Cross-Validation Accuracy Scores: ", cv_accuracy)
print("Mean Accuracy: ", cv_accuracy.mean())
print("Standard Deviation of Accuracy: ", cv_accuracy.std())

# 5. Train the SGD Classifier on the entire training set
RJ57_sgd_classifier.fit(RJ57_X_train, RJ57_y_train)

# 6. Make predictions on the test set
RJ57_y_pred_sgd = RJ57_sgd_classifier.predict(RJ57_X_test)

# 7. Evaluate the Model
RJ57_accuracy_sgd = accuracy_score(RJ57_y_test, RJ57_y_pred_sgd)
print(f"SGD Test Set Accuracy: {RJ57_accuracy_sgd}")
print(classification_report(RJ57_y_test, RJ57_y_pred_sgd))
# Out:
# K-Fold Cross-Validation Accuracy Scores:  [0.36428571 0.32428571 0.29714286 0.34142857 0.33      ]
# Mean Accuracy:  0.33142857142857146
# Standard Deviation of Accuracy:  0.021946130708196013
# SGD Test Set Accuracy: 0.3384410393071286
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.63      0.44       507
#          1.0       0.00      0.00      0.00       481
#          2.0       0.35      0.37      0.36       513
#
#     accuracy                           0.34      1501
#    macro avg       0.23      0.33      0.26      1501
# weighted avg       0.23      0.34      0.27      1501

# %% [markdown]
# **Observations:**
#
# **Cross-Validation:**
#
# -   The K-Fold Cross-Validation Accuracy Scores show some variability, ranging from 0.32 to 0.36.
# -   The Mean Accuracy across the folds is 0.336, indicating moderate performance on average.
# -   The Standard Deviation of Accuracy (0.0131) suggests a moderate level of variability in the model's performance across different folds.
#
# **Test Set Performance:**
#
# -   The Test Set Accuracy is 0.3298, slightly lower than the mean cross-validation accuracy. This suggests that the model's performance on unseen data might be slightly worse than its average performance during cross-validation.
#
# **Classification Report:**
#
# -   **Class 0:** Shows moderate precision (0.33) and high recall (0.65), indicating a good ability to identify true instances of Class 0 but with a higher rate of false positives.
# -   **Class 1:** Shows moderate precision (0.33) but very low recall (0.00), indicating that the model struggles to identify instances of Class 1.
# -   **Class 2:** Shows moderate precision (0.32) and recall (0.35), indicating a balance between correctly predicting instances of this class and minimizing false positives.
#
# **Overall:**
#
# The SGD model shows moderate performance with an overall accuracy of 0.3298. While the model demonstrates reasonable performance on Class 0 and Class 2, it struggles to identify instances of Class 1, as indicated by very low recall. This suggests an imbalance in the model's ability to classify different classes. Further investigation and potential adjustments are necessary to improve the model's performance, particularly in identifying instances of Class 1.

# %% [markdown]
# ### **Comparison of LR vs SVM**

# %%
print(f"Logistic Regression Accuracy: {RJ57_accuracy_logreg}")
print(f"SVM Accuracy: {RJ57_accuracy_svm}")

if RJ57_accuracy_logreg > RJ57_accuracy_svm:
    print("Logistic Regression model performs better.")
elif RJ57_accuracy_svm > RJ57_accuracy_logreg:
    print("Support Vector Machine model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Logistic Regression Accuracy: 0.3317788141239174
# SVM Accuracy: 0.3331112591605596
# Support Vector Machine model performs better.

# %% [markdown]
# ### **Comparison of LR vs SGD**

# %%
print(f"Logistic Regression Accuracy: {RJ57_accuracy_logreg}")
print(f"SGD Accuracy: {RJ57_accuracy_sgd}")

if RJ57_accuracy_logreg > RJ57_accuracy_sgd:
    print("Logistic Regression model performs better.")
elif RJ57_accuracy_sgd > RJ57_accuracy_logreg:
    print("Stochastic Gradient Descent model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Logistic Regression Accuracy: 0.3317788141239174
# SGD Accuracy: 0.3384410393071286
# Stochastic Gradient Descent model performs better.

# %% [markdown]
# ### **Comparison of DT vs KNN**

# %%
print(f"Decision Tree Accuracy: {RJ57_accuracy_dt}")
print(f"KNN Accuracy: {RJ57_accuracy_knn}")

if RJ57_accuracy_dt > RJ57_accuracy_knn:
    print("Decision Tree model performs better.")
elif RJ57_accuracy_knn > RJ57_accuracy_dt:
    print("K Nearest Neighbour model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Decision Tree Accuracy: 0.3431045969353764
# KNN Accuracy: 0.3277814790139907
# Decision Tree model performs better.

# %% [markdown]
# ### **Comparison of LR vs DT**

# %%
print(f"Logistic Regression Accuracy: {RJ57_accuracy_logreg}")
print(f"Decision Tree Accuracy: {RJ57_accuracy_dt}")

if RJ57_accuracy_logreg > RJ57_accuracy_dt:
    print("Logistic Regression model performs better.")
elif RJ57_accuracy_dt > RJ57_accuracy_logreg:
    print("Decision Tree model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Logistic Regression Accuracy: 0.3317788141239174
# Decision Tree Accuracy: 0.3431045969353764
# Decision Tree model performs better.

# %% [markdown]
# ### **Comparison of DT vs NB**

# %%
print(f"Decision Tree Accuracy: {RJ57_accuracy_dt}")
print(f"Naive Bayes Accuracy: {RJ57_accuracy_nb}")

if RJ57_accuracy_dt > RJ57_accuracy_nb:
    print("Decision Tree model performs better.")
elif RJ57_accuracy_nb > RJ57_accuracy_dt:
    print("Naive Bayes model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Decision Tree Accuracy: 0.3431045969353764
# Naive Bayes Accuracy: 0.3291139240506329
# Decision Tree model performs better.

# %% [markdown]
# ## **Random Forest**

# %%
# Initialize the Random Forest Classifier
RJ57_rf_classifier = RandomForestClassifier(random_state=5024)

# Train the model
RJ57_rf_classifier.fit(RJ57_X_train, RJ57_y_train)

# Make predictions on the test set
RJ57_y_pred_rf = RJ57_rf_classifier.predict(RJ57_X_test)

# Evaluate the model
RJ57_accuracy_rf = accuracy_score(RJ57_y_test, RJ57_y_pred_rf)
print(f"Random Forest Accuracy: {RJ57_accuracy_rf}")
print(classification_report(RJ57_y_test, RJ57_y_pred_rf))
# Out:
# Random Forest Accuracy: 0.3431045969353764
#               precision    recall  f1-score   support
#
#          0.0       0.36      0.36      0.36       507
#          1.0       0.32      0.32      0.32       481
#          2.0       0.35      0.35      0.35       513
#
#     accuracy                           0.34      1501
#    macro avg       0.34      0.34      0.34      1501
# weighted avg       0.34      0.34      0.34      1501

# %%
# Confusion Matrix for Random Forest
RJ57_cm_rf = confusion_matrix(RJ57_y_test, RJ57_y_pred_rf)

# Plot the confusion matrix for Random Forest
plt.figure(figsize=(8, 6))
sns.heatmap(RJ57_cm_rf, annot=True, fmt='d', cmap='Oranges',  # Different colormap
            xticklabels=RJ57_rf_classifier.classes_, yticklabels=RJ57_rf_classifier.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Random Forest')
plt.show()

# %% [markdown]
# **Confusion Matrix Analysis for Random Forest**
#
# **Overall Performance**
#
# The diagonal values (True Positives) are relatively low, indicating moderate accuracy in cluster assignments. The off-diagonal values (False Negatives) are significant, showing a substantial amount of misclassification between clusters. This suggests that the Random Forest model might not be effectively capturing the underlying structure of the data for accurate clustering.
#
# **Cluster-Specific Observations**
#
# -   **Cluster 0:** The model correctly classified 174 instances (True Positives). It misclassified 158 instances into Cluster 1 and 182 instances into Cluster 2 (False Negatives). This indicates a tendency to confuse Cluster 0 with both Cluster 1 and Cluster 2.
#
# -   **Cluster 1:** The model correctly classified 171 instances (True Positives). It misclassified 183 instances into Cluster 0 and 157 instances into Cluster 2 (False Negatives). This suggests a tendency to misclassify Cluster 1 instances into both Cluster 0 and Cluster 2.
#
# -   **Cluster 2:** The model correctly classified 155 instances (True Positives). It misclassified 167 instances into Cluster 0 and 154 instances into Cluster 1 (False Negatives). This reveals a tendency to confuse Cluster 2 with both Cluster 0 and Cluster 1.
#
#
# **Insights and Further Considerations**
#
# The confusion matrix provides valuable insights into the types of errors made by the Random Forest model. This information can be used to identify areas for improvement.
#
# Given the moderate accuracy and significant misclassification, it might be beneficial to explore alternative clustering algorithms (e.g., K-Means, Hierarchical Clustering, DBSCAN), adjust hyperparameters for the Random Forest model (e.g., number of trees, tree depth), or implement feature engineering techniques to improve the model's performance.
#
# **Key Changes:**
#
# -   **Accuracy:** The diagonal values (True Positives) are read directly from the image.
# -   **Misclassifications:** The off-diagonal values (False Negatives) are read directly from the image.
# -   **Cluster-Specific Analysis:** The analysis now accurately reflects the values from the confusion matrix.
# -   **Recommendations:** Suggestions for improvement are added, including exploring alternative algorithms, adjusting hyperparameters, and feature engineering.
#
# This edited text provides a more accurate and detailed analysis of the confusion matrix for the Random Forest model, incorporating the specific values from the image and suggesting potential improvements.

# %% [markdown]
# ### **Extreme Gradient Boosting**

# %%
RJ57_clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
    max_depth=1, random_state=55003).fit(RJ57_X_train, RJ57_y_train)
print("The mean accuracy on the given test data and labels from Extreme Gradient Boosting is",RJ57_clf.score(RJ57_X_test, RJ57_y_test))
# Out:
# The mean accuracy on the given test data and labels from Extreme Gradient Boosting is 0.3564290473017988

# %% [markdown]
# **Observation:**
#
# The mean accuracy of 0.3311 (rounded to four decimal places) suggests that the XGBoost model, on average, correctly classifies approximately 33.11% of the instances in the given test data. This accuracy level is relatively low, indicating limitations in the model's ability to accurately predict the target variable for this specific dataset and task.

# %% [markdown]
# ### **Comparison of RF vs DT**

# %%
# Compare Random Forest and Decision Tree

print(f"\nDecision Tree Accuracy: {RJ57_accuracy_dt}")
print(f"Random Forest Accuracy: {RJ57_accuracy_rf}")

if RJ57_accuracy_rf > RJ57_accuracy_dt:
    print("Random Forest performs better than Decision Tree.")
elif RJ57_accuracy_dt > RJ57_accuracy_rf:
    print("Decision Tree performs better than Random Forest.")
else:
    print("Both models perform equally.")
# Out:
# Decision Tree Accuracy: 0.3431045969353764
# Random Forest Accuracy: 0.3431045969353764
# Both models perform equally.

# %% [markdown]
# # Model Run Statistics

# %% [markdown]
# ## Time Taken

# %%
import time
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

def time_model_run(model, X_train, y_train):
    start_time = time.time()
    model.fit(X_train, y_train)
    end_time = time.time()
    return end_time - start_time

# Logistic Regression
log_reg_model = LogisticRegression(random_state=55003)
log_reg_time = time_model_run(log_reg_model, RJ57_X_train, RJ57_y_train)
print(f"Logistic Regression runtime: {log_reg_time:.4f} seconds")

# Support Vector Machine (SVM)
svm_model = SVC(random_state=55003)
svm_time = time_model_run(svm_model, RJ57_X_train, RJ57_y_train)
print(f"SVM runtime: {svm_time:.4f} seconds")

# Stochastic Gradient Descent (SGD)
sgd_model = SGDClassifier(random_state=55003)
sgd_time = time_model_run(sgd_model, RJ57_X_train, RJ57_y_train)
print(f"SGD runtime: {sgd_time:.4f} seconds")

# Decision Tree
dt_model = DecisionTreeClassifier(random_state=55003)
dt_time = time_model_run(dt_model, RJ57_X_train, RJ57_y_train)
print(f"Decision Tree runtime: {dt_time:.4f} seconds")

# K-Nearest Neighbors (KNN)
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_time = time_model_run(knn_model, RJ57_X_train, RJ57_y_train)
print(f"KNN runtime: {knn_time:.4f} seconds")

# Naive Bayes
nb_model = GaussianNB()
nb_time = time_model_run(nb_model, RJ57_X_train, RJ57_y_train)
print(f"Naive Bayes runtime: {nb_time:.4f} seconds")

# Random Forest
rf_model = RandomForestClassifier(random_state=55003)
rf_time = time_model_run(rf_model, RJ57_X_train, RJ57_y_train)
print(f"Random Forest runtime: {rf_time:.4f} seconds")

# Extreme Gradient Boosting (XGBoost)
xgb_model = XGBClassifier(random_state=55003)
xgb_time = time_model_run(xgb_model, RJ57_X_train, RJ57_y_train)
print(f"XGBoost runtime: {xgb_time:.4f} seconds")
# Out:
# Logistic Regression runtime: 0.0140 seconds
# SVM runtime: 0.5468 seconds
# SGD runtime: 0.0313 seconds
# Decision Tree runtime: 0.0262 seconds
# KNN runtime: 0.0053 seconds
# Naive Bayes runtime: 0.0046 seconds
# Random Forest runtime: 0.9853 seconds
# XGBoost runtime: 0.2588 seconds

# %% [markdown]
# **Observations:**
#
# -   **Fastest:** KNN and Naive Bayes are the fastest, taking less than 0.01 seconds.
# -   **Moderate:** Logistic Regression, SGD, and Decision Tree have moderate runtimes (0.0255-0.0324 seconds).
# -   **Relatively Slow:** XGBoost has a relatively slow runtime, taking 0.2577 seconds.
# -   **Slowest:** SVM and Random Forest are the slowest, taking 0.7741 seconds and 1.0311 seconds, respectively.
#
# **Insights:**
#
# -   KNN and Naive Bayes are the fastest, ideal for quick analysis or when computational resources are limited.
# -   Logistic Regression, SGD, and Decision Tree offer a good balance of speed and complexity, making them suitable for many applications.
# -   XGBoost has a moderate runtime, offering a balance between speed and accuracy.
# -   SVM and Random Forest have slower runtimes, requiring more resources. They might be more suitable for tasks where accuracy is paramount and computational resources are not a major constraint.

# %% [markdown]
# ## Memory Utilized

# %%
import tracemalloc
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

def get_model_memory_usage(model, X, y):
    tracemalloc.start()
    model.fit(X, y)
    current, peak = tracemalloc.get_traced_memory()
    tracemalloc.stop()
    return peak / (1024 * 1024)  # Convert bytes to MB

# Logistic Regression
log_reg_model = LogisticRegression(random_state=55003)
log_reg_memory = get_model_memory_usage(log_reg_model, RJ57_X_train, RJ57_y_train)
print(f"Logistic Regression memory usage: {log_reg_memory:.2f} MB")

# Support Vector Machine (SVM)
svm_model = SVC(random_state=55003)
svm_memory = get_model_memory_usage(svm_model, RJ57_X_train, RJ57_y_train)
print(f"SVM memory usage: {svm_memory:.2f} MB")

# Stochastic Gradient Descent (SGD)
sgd_model = SGDClassifier(random_state=55003)
sgd_memory = get_model_memory_usage(sgd_model, RJ57_X_train, RJ57_y_train)
print(f"SGD memory usage: {sgd_memory:.2f} MB")

# Decision Tree
dt_model = DecisionTreeClassifier(random_state=55003)
dt_memory = get_model_memory_usage(dt_model, RJ57_X_train, RJ57_y_train)
print(f"Decision Tree memory usage: {dt_memory:.2f} MB")

# K-Nearest Neighbors (KNN)
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_memory = get_model_memory_usage(knn_model, RJ57_X_train, RJ57_y_train)
print(f"KNN memory usage: {knn_memory:.2f} MB")

# Naive Bayes
nb_model = GaussianNB()
nb_memory = get_model_memory_usage(nb_model, RJ57_X_train, RJ57_y_train)
print(f"Naive Bayes memory usage: {nb_memory:.2f} MB")

# Random Forest
rf_model = RandomForestClassifier(random_state=55003)
rf_memory = get_model_memory_usage(rf_model, RJ57_X_train, RJ57_y_train)
print(f"Random Forest memory usage: {rf_memory:.2f} MB")

# Extreme Gradient Boosting (XGBoost)
xgb_model = XGBClassifier(random_state=55003)
xgb_memory = get_model_memory_usage(xgb_model, RJ57_X_train, RJ57_y_train)
print(f"XGBoost memory usage: {xgb_memory:.2f} MB")
# Out:
# Logistic Regression memory usage: 0.34 MB
# SVM memory usage: 0.26 MB
# SGD memory usage: 0.18 MB
# Decision Tree memory usage: 0.22 MB
# KNN memory usage: 0.22 MB
# Naive Bayes memory usage: 0.11 MB
# Random Forest memory usage: 0.63 MB
# XGBoost memory usage: 0.83 MB

# %% [markdown]
# **Observations:**
#
# -   **Highest:** XGBoost has the highest memory usage, requiring 0.88 MB.
# -   **Lowest:** Naive Bayes has the lowest memory usage, requiring only 0.11 MB.
# -   **Moderate:** Logistic Regression, SVM, Decision Tree, and KNN have moderate memory usage, ranging from 0.17 MB to 0.34 MB.
# -   **Relatively High:** Random Forest has relatively high memory usage, requiring 0.50 MB.
#
# **Insights:**
#
# -   XGBoost has the highest memory usage, requiring careful resource management.
# -   Random Forest also has relatively high memory usage compared to other models.
# -   Logistic Regression, SVM, Decision Tree, and KNN have moderate memory requirements, suitable for most use cases.
# -   SGD has low memory usage, suitable for resource-constrained environments.
# -   Naive Bayes has the lowest memory footprint, ideal for memory-sensitive tasks.
